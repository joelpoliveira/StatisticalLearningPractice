# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
import sklearn.datasets as data_sets

# %%
mat = np.array([[0, 3, 0, 0],
               [2, 0, 0, 0],
               [0, 1, 3, 0],
               [0, 1, 2, 1],
               [-1, 0, 1, 1],
               [1, 1, 1, 0]], dtype = int)

# %%
 def euclidean_dist(a, b):
        return np.sqrt( np.sum( (a[:-1]-b[:-1])**2 ) )

# %%
arr = np.array([0,0,0,np.nan])
dist_mat = np.array(list(map(lambda x: euclidean_dist(x, arr), mat)))

# %%
dist_mat
# Out:
# array([3.        , 2.        , 3.16227766, 2.23606798, 1.41421356,
#        1.73205081])

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
color = {0: 'r', 1: 'g'}
ax.scatter(mat[:, 0], mat[:, 1], mat[:, 2], c = list(map(lambda x : color[x], mat[:,3])))
ax.scatter(0,0,0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
col = pd.read_csv("College.csv" )

# %%
col
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
col.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# %matplotlib inline
sns.pairplot(col[col.columns[:10]])

# %%
sns.boxplot(x = 'Private', y = 'Outstate', data = col, orient='v')
# Out:
# <AxesSubplot:xlabel='Private', ylabel='Outstate'>

# %%
col.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
col['Elite'] = col['Top10perc'].apply(lambda x: 1 if x > 50 else 0)

# %%
col['Elite'].sum()
# Out:
# 78

# %%
sns.boxplot(x = 'Elite', y = 'Outstate', data = col, orient='v')
# Out:
# <AxesSubplot:xlabel='Elite', ylabel='Outstate'>

# %%
sns.heatmap(col.corr())
# Out:
# <AxesSubplot:>

# %%
np.abs(col.corr())
# Out:
#                  Apps    Accept    Enroll  Top10perc  Top25perc  F.Undergrad  \
# Apps         1.000000  0.943451  0.846822   0.338834   0.351640     0.814491
# Accept       0.943451  1.000000  0.911637   0.192447   0.247476     0.874223
# Enroll       0.846822  0.911637  1.000000   0.181294   0.226745     0.964640
# Top10perc    0.338834  0.192447  0.181294   1.000000   0.891995     0.141289
# Top25perc    0.351640  0.247476  0.226745   0.891995   1.000000     0.199445
# F.Undergrad  0.814491  0.874223  0.964640   0.141289   0.199445     1.000000
# P.Undergrad  0.398264  0.441271  0.513069   0.105356   0.053577     0.570512
# Outstate     0.050159  0.025755  0.155477   0.562331   0.489394     0.215742
# Room.Board   0.164939  0.090899  0.040232   0.371480   0.331490     0.068890
# Books        0.132559  0.113525  0.112711   0.118858   0.115527     0.115550
# Personal     0.178731  0.200989  0.280929   0.093316   0.080810     0.317200
# ...

# %%
auto = pd.read_csv('Auto.csv')

# %%
auto = auto.applymap(lambda x: np.nan if x=='?' else x).dropna()

# %%
auto.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
# 5  15.0          8         429.0         198    4341          10.0    70
# 6  14.0          8         454.0         220    4354           9.0    70
# 7  14.0          8         440.0         215    4312           8.5    70
# 8  14.0          8         455.0         225    4425          10.0    70
# 9  15.0          8         390.0         190    3850           8.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 38.7+ KB

# %%
auto.horsepower = auto.horsepower.apply(lambda x: int(x))

# %%
np.unique(auto.origin)
# Out:
# array([1, 2, 3], dtype=int64)

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
auto.mean()
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# origin             1.576531
# dtype: float64

# %%
auto.std()
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# origin            0.805518
# dtype: float64

# %%
auto.reset_index(inplace = True)

# %%
auto.drop([i for i in range(10, 86)], inplace=True)

# %%
auto = auto.drop(['index'], axis = 1)

# %%
auto.mean()
# Out:
# mpg               24.407595
# cylinders          5.373418
# displacement     187.512658
# horsepower       100.848101
# weight          2936.534810
# acceleration      15.717405
# year              77.136076
# origin             1.601266
# dtype: float64

# %%
auto.std()
# Out:
# mpg               7.863285
# cylinders         1.654179
# displacement    100.114616
# horsepower       35.954147
# weight          811.874450
# acceleration      2.713876
# year              3.123464
# origin            0.819910
# dtype: float64

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.mpg.unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 13. , 12. , 23. , 26. , 11. , 20. ,
#        21. , 22. , 19. , 29. , 24. , 31. , 32. , 25. , 28. , 33. , 27. ,
#        17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5, 26.5, 16.5, 31.5, 30. ,
#        36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1, 32.8, 39.4, 19.9,
#        19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1, 17.7, 27.5, 27.2,
#        30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2, 19.8, 22.3, 17.6,
#        18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2, 34.5, 31.8, 37.3,
#        28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4, 24.3, 19.1, 34.3,
#        29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3, 43.4, 36.4, 44.6,
#        33.8, 32.7, 23.7, 35. , 32.4, 26.6, 25.8, 23.5, 39.1, 39. , 35.1,
#        32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9, 31.6, 28.1, 30.7, 24.2,
#        22.4, 34. , 38. , 44. ])

# %%
sns.regplot(x = 'displacement', y = 'mpg', data = auto)
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
# %matplotlib notebook 
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
colors = {}
ax.scatter(auto.horsepower, auto.weight, auto.displacement, c = auto.mpg)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
boston = data_sets.load_boston()

# %%
boston = pd.DataFrame(data=boston['data'], columns=boston['feature_names'])

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston.shape
# Out:
# (506, 13)

# %%
sns.heatmap(boston.corr())
# Out:
# <AxesSubplot:>

# %%
boston.corr()['CRIM']
# Out:
# CRIM       1.000000
# ZN        -0.200469
# INDUS      0.406583
# CHAS      -0.055892
# NOX        0.420972
# RM        -0.219247
# AGE        0.352734
# DIS       -0.379670
# RAD        0.625505
# TAX        0.582764
# PTRATIO    0.289946
# B         -0.385064
# LSTAT      0.455621
# Name: CRIM, dtype: float64

# %%
# %matplotlib notebook
sns.pairplot(boston)
# Out:
# <img src="data:image/png;base64,..." width="2340">
